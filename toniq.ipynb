# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.4 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/8.1 MB 1.6 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.1 MB 1.7 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.8 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.1 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.1 MB 1.8 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.1 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 1.9 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 1.8 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.1 MB 1.8 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 1.8 MB/s eta 0:00:03
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
prod = pd.read_csv(r"E:\2026\PROJECCTS\Inventory Intelligence\products_export.csv")

# %%
cat = pd.read_csv(r"E:\2026\PROJECCTS\Inventory Intelligence\categories_export.csv")

# %%
cat['vendor']=cat['Item Sort Order'].str.extract((r'\(([A-Z]+)\)'))

# %%
cat.head()
# Out:
#      Category ID Category Name  \
# 0  KNBQ2K17X8TQW   Quick Items
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
#
#                                      Item Sort Order vendor
# 0                   White Reusable T-Shirt Bag (CGD)    CGD
# 1                              Brown Paper Bag (CGD)    CGD
# 2                                    White Paper Bag    NaN
# 3                              Book of Matches (CGD)    CGD
# 4  Chapstick: Moisturizer Lip Balm 0.15 oz Stick ...    KUD

# %%
cat=cat.rename(columns={'Item Sort Order':'Name'})

# %%
cat= cat.drop(columns= ['Category ID','Category Name'], axis=1)

# %%
cat.loc[(cat['vendor'].isnull()) & (cat['Name'].str.contains('Frito',na=False)),'vendor']='Frito'

# %%
prod['vendor'] = prod['Name'].str.extract((r'\(([A-Z]+)\)'))

# %%
prod.loc[(prod['vendor'].isnull()) &(prod['Name'].str.contains('Frito',na=False)),'vendor']="Frito"

# %%
toniq=pd.merge(prod,cat, on='Name')

# %%
toniq.shape
# Out:
# (33702, 22)

# %%
toniq = toniq.to_csv("toniq.csv")

# %%
toniq.head()
# Out:
#        Clover ID                                               Name  \
# 0  N4Y8KG8T5PG8P  Idaho Spuds: Mashed Potatoes - Classic 13.3 oz...
# 1  R6PP2FC4SDPGE                 Hunt's: Diced Tomatoes 14.5 oz Can
# 2  91MTVKH1DVRSE                      Hunt's: Tomato Paste 6 oz Can
# 3  KZZPGWGPW5FM6                        JJ's Bakery: Lemon Pie 4 oz
# 4  AXEPXBXWDH3M8       Spicy Guys: Extra Spicy Pretzels 2.25 oz Bag
#
#    Alternate Name  Description  Price Price Type  Price Unit   Cost  \
# 0             NaN          NaN  $3.29      Fixed         NaN  $1.77
# 1             NaN          NaN  $1.69      Fixed         NaN  $0.62
# 2             NaN          NaN  $1.89      Fixed         NaN  $1.00
# 3             NaN          NaN  $1.29      Fixed         NaN  $0.56
# 4             NaN          NaN  $2.99      Fixed         NaN  $1.32
#
#    Product Code           SKU  ...  Default tax rates? Non-revenue item?  \
# ...
